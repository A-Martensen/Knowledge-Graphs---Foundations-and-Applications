# %% [markdown]
# <a href="https://colab.research.google.com/github/A-Martensen/Knowledge-Graphs---Foundations-and-Applications/blob/main/Week_1_2_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### <font color='red'>NOTE: Please do not edit this file. </font> Go to <font color='blue'>*File > Save a copy in Drive*</font>.
#
# # **openHPI Course: Knowledge Graphs 2023**
# ## **Week 1: Knowledge Representation with Graphs**
# ### **Hands-On 1.2: NLP**
#
# ---
#
#
# This is the first Python notebook for week 1 (Knowledge Representation with Graphs) in the openHPI Course **Knowledge Graphs 2023**.
#
# In this notebook you will learn the basics of Natural Language Processing (NLP).
#
# - For the rest of this hands-on session, we will be using data uploaded in this [Google Drive](https://drive.google.com/drive/folders/15HNd46z9G2tuN35LzYox8gf_bJbyjNzb?usp=sharing) folder.
# - Make a copy of this folder into your own machine and/or to your Google Drive.

# %% [markdown]
# # <a name="TOC"></a> Table of Contents:
# 1. Google Colab Basics
# 2. The Art of Understanding: Natural Language Processing ([NLP](#2-nlp))
#   - [Tokenization](#nlp-tokenization)
#   - Morphological and Syntactic Analysis
#     - [Lemmatization](#nlp-lemma)
#     - [Part-of-Speech Tagging](#nlp-pos)
#     - [Dependency Parsing](#nlp-dep)
#   - [Named Entity Recognition](#nlp-ner)

# %% [markdown]
# # <a name="1-google collab"></a> 1. Google Colab Basics

# %% [markdown]
# ### 1.1 How to upload files from your local machine to this notebook?
#   First things first, let's load *star-trek.json* file from your local machine into this notebook.

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
import json
from pathlib import Path

DATA = Path("Data_Hands-On_1.2")

with open(DATA / "star-trek.json", encoding="utf-8") as f:
    data = json.load(f)

# %% [markdown]
# ### 1.2 How to upload files from Google Drive to this notebook?
#   - Using [PyDrive](https://pythonhosted.org/PyDrive/)

# %%
# !pip install -U -q PyDrive
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive
# from google.colab import auth
# from oauth2client.client import GoogleCredentials

# auth.authenticate_user()
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)

# %% [markdown]
# - After executing the code above, Colab will prompt you to **allow Google to have access to your Drive**. Allow permission then go to your Drive, right-click *star-trek.json* and select "Get link."

# %%
# link = "https://drive.google.com/file/d/1BYbGVY2tr4nSMb2XGG3tXZlVC2R1YjH1/view?usp=drive_link"
# file_id = link.split('/')[-2]
# # We are only interested in the file id
# print(f' File ID: {file_id}')

# downloaded = drive.CreateFile({'id':file_id})
# downloaded.GetContentFile('star-trek.json')

# %% [markdown]
# ---

# %% [markdown]
# # <a name="2-nlp"></a> 2. Natural Language Processing
#
# As discussed in the lecture in section **1.3 The Art of Understanding**, the process of understanding relies on the correct interpretation of various aspects of natural language.

# %% [markdown]
# ![nlu](https://drive.google.com/uc?id=1kMwWjG5gYvRvw7YBYt_ujBfA90hE3kE3)

# %% [markdown]
# In this notebook, we will take a look at some of the NLP techniques implemented with [SpaCy](https://spacy.io) python library using the `en_core_web_sm` [model](https://spacy.io/models/en), which is an English language pipeline optimized for CPU and was trained on blog entries, news articles and online comments.
#
# ## <a name="nlp-tokenization"></a> 2.1 Tokenization
# Tokenization is the **process of separating character sequences** into
# smaller pieces, called **tokens**. In this process, certain characters
# might be omitted, such as punctuation, depending on the rules of the individual language model.
#
# For this example, let's use an excerpt from Leonard Nimoy's [Wikipedia page](https://en.wikipedia.org/wiki/Leonard_Nimoy):
#
# > *Leonard Simon Nimoy was born on March 26, 1931, in an Irish section of West End of Boston, Massachusetts, to Jewish immigrants from Iziaslav, Ukraine. His mother, Dora (née Spinner; 1904–1987), was a homemaker, and his father, Max Nimoy (1901–1987), owned a barbershop in the Mattapan section of Boston. Leonard Simon Nimoy was an American actor, famed for playing Spock in the Star Trek franchise for almost 50 years.*

# %%
#First we have to import the spaCy library and download the language models
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp('Leonard Simon Nimoy was born on March 26, 1931, in an Irish section \
of West End of Boston, Massachusetts, to Jewish immigrants from Iziaslav, Ukraine. \
His mother, Dora (née Spinner; 1904–1987), was a homemaker, and his father, \
Max Nimoy (1901–1987), owned a barbershop in the Mattapan section of Boston. \
Leonard Simon Nimoy was an American actor, famed for playing Spock in the Star Trek \
franchise for almost 50 years.')

# Let's view the first 10 tokens
for token in doc[:10]:
  print(token.text)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 #First we have to import the spaCy library and download the language models
# ----> 2 import spacy
#       3
#       4 nlp = spacy.load("en_core_web_sm")
#       5 doc = nlp('Leonard Simon Nimoy was born on March 26, 1931, in an Irish section \
#
# File c:\Workspace\Knowledge-Graphs---Foundations-and-Applications\.venv\Lib\site-packages\spacy\__init__.py:13
#      10 # These are imported as part of the API
#      11 from thinc.api import Config, prefer_gpu, require_cpu, require_gpu  # noqa: F401
# ---> 13 from . import (
#      14     pipeline,  # noqa: F401
#      15     util,
#      16 )
#      17 from .about import __version__  # noqa: F401
#      18 from .cli.info import info  # noqa: F401
#
# File c:\Workspace\Knowledge-Graphs---Foundations-and-Applications\.venv\Lib\site-packages\spacy\pipeline\__init__.py:3
#       1 from .attributeruler import AttributeRuler
#       2 from .dep_parser import DependencyParser
# ----> 3 from .edit_tree_lemmatizer import EditTreeLemmatizer
#       4 from .entity_linker import EntityLinker
#       5 from .entityruler import EntityRuler
#
# File c:\Workspace\Knowledge-Graphs---Foundations-and-Applications\.venv\Lib\site-packages\spacy\pipeline\edit_tree_lemmatizer.py:17
#      15 from ..training import Example, validate_examples, validate_get_examples
#      16 from ..vocab import Vocab
# ---> 17 from ._edit_tree_internals.edit_trees import EditTrees
#      18 from ._edit_tree_internals.schemas import validate_edit_tree
#      19 from .lemmatizer import lemmatizer_score
#
# ImportError: DLL load failed while importing edit_trees: Eine Anwendungssteuerungsrichtlinie hat diese Datei blockiert.

# %% [markdown]
# Traditionally, tokenization involves initially splitting a text into sentences. SpaCy makes it possible to retrieve sentences from the [Doc](https://spacy.io/api/doc) container object.

# %%
# doc.sents - an iterator over the sentences in the Doc object
for id, sent in enumerate(doc.sents):
  print(f'Sentence {id+1}: {sent}')
# Out:
# Sentence 1: Leonard Simon Nimoy was born on March 26, 1931, in an Irish section of West End of Boston, Massachusetts, to Jewish immigrants from Iziaslav, Ukraine.
# Sentence 2: His mother, Dora (née Spinner; 1904–1987), was a homemaker, and his father, Max Nimoy (1901–1987), owned a barbershop in the Mattapan section of Boston.
# Sentence 3: Leonard Simon Nimoy was an American actor, famed for playing Spock in the Star Trek franchise for almost 50 years.

# %% [markdown]
# Under the hood, SpaCy's [Doc](https://spacy.io/api/doc) object is made up of a sequence of [Token](https://spacy.io/api/token) objects.

# %% [markdown]
# ## 2.2. Morphological and Syntactic Analysis
# The statement `doc = nlp('...')` in SpaCy is very powerful. It takes care of several NLP techniques at once: tokenization, lemmatization, Part-of-speech (POS) tagging and dependency parsing.
#
# <a name="nlp-lemma"></a>**Lemmatization** falls under the umbrella of **morphological analysis**, the study of words. It requires morphological rules and a lexicon to reduce a word to its base form. In this way, words that have different inflections can be treated as the same item. For example, the auxiliary verbs *is*, *are*, *was*, and *were* are grouped together under the lemma *be*.
#
# The latter two processes are part of **syntactic analysis**. <a name="nlp-pos"></a> With POS tagging, each word is classified according to its syntactic **part-of-speech** and labelled according to a specified tagset, while **dependency parsing** identifies the syntactic relationship that exists between tokens in a sentence.
#
# Let's now inspect SpaCy's [Token](https://spacy.io/api/token) object. Other than `token.text`, there are several linguistic annotations that we can access through this object:
#
# 1. `token.lemma_` - the base form of the word. Example: the lemma of *was* is *be*.
# 2. `token.pos_` - simple part-of-speech tag according to the [UPOS](https://universaldependencies.org/u/pos/).
# 3. `token.tag_` - detailed part-of-speech tag according to the [Penn](https://cs.nyu.edu/~grishman/jet/guide/PennPOS.html).
# 4. `token.dep_` - syntactic dependency to describe the relationship between phrases in that sentence.

# %%
token_details = []
for idx, token in enumerate(doc):
  token_details.append((idx, token.text, token.lemma_, token.pos_, token.tag_, token.dep_))

# %% [markdown]
# Let's print out the first 25 tokens and their attributes in tabular form.

# %%
from tabulate import tabulate

print(tabulate(token_details[:25], headers=['ID', 'TEXT', 'LEMMA', 'POS', 'TAG', 'DEP']))
# Out:
#   ID  TEXT           LEMMA          POS    TAG    DEP
# ----  -------------  -------------  -----  -----  ---------
#    0  Leonard        Leonard        PROPN  NNP    compound
#    1  Simon          Simon          PROPN  NNP    compound
#    2  Nimoy          Nimoy          PROPN  NNP    nsubjpass
#    3  was            be             AUX    VBD    auxpass
#    4  born           bear           VERB   VBN    ROOT
#    5  on             on             ADP    IN     prep
#    6  March          March          PROPN  NNP    pobj
#    7  26             26             NUM    CD     nummod
#    8  ,              ,              PUNCT  ,      punct
#    9  1931           1931           NUM    CD     nummod
#   10  ,              ,              PUNCT  ,      punct
#   11  in             in             ADP    IN     prep
#   12  an             an             DET    DT     det
#   13  Irish          irish          ADJ    JJ     amod
#   14  section        section        NOUN   NN     pobj
#   15  of             of             ADP    IN     prep
#   16  West           West           PROPN  NNP    compound
#   17  End            End            PROPN  NNP    pobj
#   18  of             of             ADP    IN     prep
#   19  Boston         Boston         PROPN  NNP    pobj
#   20  ,              ,              PUNCT  ,      punct
#   21  Massachusetts  Massachusetts  PROPN  NNP    appos
#   22  ,              ,              PUNCT  ,      punct
#   23  to             to             ADP    IN     prep
#   24  Jewish         jewish         ADJ    JJ     amod

# %% [markdown]
# ## 2.3 <a name="nlp-dept"></a>Dependency Parsing
#
# As part of syntactic analysis, dependency parsing is a process that determines and examines the grammatical relationships between phrases and words in a sentence.
#
# Each relationship is indicated by a **head** (tail of the arrow) and its modifiers, the **dependent**/s (tip of the arrow). In the diagram below, *born* is considered the head, *was* as the tail, and [auxpass](https://universaldependencies.org/docs/en/dep/auxpass.html) for passive auxiliary
#
# ![was-born](https://drive.google.com/uc?id=1OtoC1Ww1I4HIKRFyW4Rm6eSDCWabkjHW)

# %%
from spacy import displacy

for sent in doc.sents:
  displacy.render(sent, style="dep", jupyter=True, options={'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="67f8390e0e7d4e4fbac95b42cc078fbd-0" class="displacy" width="2550" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Leonard</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Simon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Nimoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">March</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">26,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">1931,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">Irish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">section</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">West</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">End</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">Boston,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Massachusetts,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">Jewish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">immigrants</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">Iziaslav,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Ukraine.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-67f8390e0e7d4e4fbac95b42cc078fbd-0-0" stroke-width="2px" d="M70,202.0 C70,102.0 240.0,102.0 240.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-67f8390e0e7d4e4fbac95b42cc078fbd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-67f8390e0e7d4e4fbac95b42cc078fbd-0-1" stroke-width="2px" d="M170,202.0 C170,152.0 235.0,152.0 235.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-67f8390e0e7d4e4fbac95b42cc078fbd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-67f8390e0e7d4e4fbac95b42cc078fbd-0-2" stroke-width="2px" d="M270,202.0 C270,102.0 440.0,102.0 440.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dbb68d0f7d60403396ee19fb396ad0a7-0" class="displacy" width="2450" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">His</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">mother,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Dora (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">née</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">Spinner;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">1904–1987),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">homemaker,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">father,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Max</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">Nimoy (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">1901–1987),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">owned</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">barbershop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">Mattapan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">section</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">Boston.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dbb68d0f7d60403396ee19fb396ad0a7-0-0" stroke-width="2px" d="M70,202.0 C70,152.0 135.0,152.0 135.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dbb68d0f7d60403396ee19fb396ad0a7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dbb68d0f7d60403396ee19fb396ad0a7-0-1" stroke-width="2px" d="M170,202.0 C170,2.0 650.0,2.0 650.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dbb68d0f7d60403396ee19fb396ad0a7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dbb68d0f7d60403396ee19fb396ad0a7-0-2" stroke-width="2px" d="M270,202.0 C270,102.0 440.0,102.0 440.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dbb68d0f7d60403396ee19fb396ad0a7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e81388963048429ebe9a88720345012d-0" class="displacy" width="2050" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Leonard</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Simon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Nimoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">American</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">actor,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">famed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">playing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">Spock</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">Star</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Trek</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">franchise</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">almost</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">50</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">years.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e81388963048429ebe9a88720345012d-0-0" stroke-width="2px" d="M70,202.0 C70,102.0 240.0,102.0 240.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e81388963048429ebe9a88720345012d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e81388963048429ebe9a88720345012d-0-1" stroke-width="2px" d="M170,202.0 C170,152.0 235.0,152.0 235.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e81388963048429ebe9a88720345012d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e81388963048429ebe9a88720345012d-0-2" stroke-width="2px" d="M270,202.0 C270,152.0 335.0,152.0 335.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e81388963048429ebe9a88720345012d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e81388963048429ebe9a88720345012d-0-3" stroke-width="2px" d="M470,202.0 C470,102.0 640.0,102.0 640.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e81388963048429ebe9a88720345012d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,204.0 L462,192.0 478,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e81388963048429ebe9a88720345012d-0-4" stroke-width="2px" d="M570,202.0 C570,152.0 635.0,152.0 635.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e81388963048429ebe9a88720345012d-0-4" class="displacy-label" startOffset="50

# %% [markdown]
# ## 2.4 <a name="nlp-ner"></a>Named Entity Recognition (NER)
# Recall from [1.4 Graphs and Triples](https://docs.google.com/presentation/d/147-hjulZqnsuSfK-66NGq8GfTTNmeUNjew5XjQ8IrzI/edit?usp=sharing) that graphs are constructed from *triples*. Each triple is composed of two vertices connected with a directed edge. The *vertices* are the entities, while the *edges* represent the relationships that exist between an entity pair.

# %% [markdown]
# ![triple](https://drive.google.com/uc?id=1BMERaNGHJADpL7FYW8qfTBoLpK00IVm5)
# ![graph](https://drive.google.com/uc?id=1JNBej83x1wJSe340lECAUQwBzFNhQIBs)

# %% [markdown]
# NER involves locating and classifying real-world objects mentioned in the sentence into categories such as **names, persons, organizations, locations, expressions of time, quantities, monetary values**, etc.
#
# SpaCy's [Doc](https://spacy.io/api/doc) object predicts these named entities and stores them in the `ents` property with the following attributes:
# 1. `ent.text`
# 2. `ent.start_char` - the position of the first character of the name mentioned in the sentence, with `0` being the first character in the sentence.
# 3. `ent.end_char` - the position of the last character of the name mentioned in the sentence.
# 4. `ent.label_` - the category, such as, ORG, GPE (Geopolitical Entity), MONEY, etc.

# %%
ner_details = []

for ent in doc.ents:
  ner_details.append((ent.text, ent.start_char, ent.end_char, ent.label_))

# %%
import pandas as pd

# for now, just for printing tabular data nicely ;)
pd.DataFrame(ner_details, columns=['TEXT', 'START', 'END', 'LABEL'])
# Out:
#                    TEXT  START  END     LABEL
# 0   Leonard Simon Nimoy      0   19    PERSON
# 1        March 26, 1931     32   46      DATE
# 2                 Irish     54   59      NORP
# 3              West End     71   79       GPE
# 4                Boston     83   89       GPE
# 5         Massachusetts     91  104       GPE
# 6                Jewish    109  115      NORP
# 7              Iziaslav    132  140       GPE
# 8               Ukraine    142  149       GPE
# 9                  Dora    163  167    PERSON
# 10              Spinner    173  180    PERSON
# 11            1904–1987    182  191  CARDINAL
# 12            Max Nimoy    227  236    PERSON
# 13            1901–1987    238  247      DATE
# 14             Mattapan    276  284       ORG
# 15               Boston    296  302       GPE
# 16  Leonard Simon Nimoy    304  323    PERSON
# 17             American    331  339      NORP
# 18                Spock    365  370    PERSON
# 19      almost 50 years    402  417      DATE

# %%
from spacy import displacy

# Let's use displacy to display the entities.
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Leonard Simon Nimoy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was born on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 26, 1931
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , in an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  section of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     West End
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Massachusetts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , to
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jewish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  immigrants from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iziaslav
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . His mother,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (née
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spinner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1904–1987
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ), was a homemaker, and his father,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Max Nimoy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1901–1987
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ), owned a barbershop in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mattapan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  section of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Leonard Simon Nimoy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  actor, famed for playing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spock
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in the Star Trek franchise for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     almost 50 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>

# %% [markdown]
# To determine the description of the entity labels, simply use `spacy.explain(label)`.

# %%
spacy.explain('NORP')
# Out:
# 'Nationalities or religious or political groups'

# %%
spacy.explain('auxpass')
# Out:
# 'auxiliary (passive)'

# %% [markdown]
# Inspecting the results of the NER and the dependency graph, we can observe the following patterns: nouns and noun phrases are identified as entities, while verbal, prepositional, and adjectival phrases signify relations.

# %% [markdown]
# In summary, syntactical analysis of texts is often straightforward. Unfortunately, the same cannot be said when it comes to semantics. The succeeding section illustrates the complexity in understanding the meaning of words.
